# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv("../data/test_df_en.csv", sep=";")
data = data.drop(data.columns[0], axis=1)

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

stop_words = set(stopwords.words('english'))
stop_words.update(['I', 'aye', 'oh', 'ho', 'uh', 'yeah','wa','hey','da','duh','ooh','ohh',
                   'la','yo','ya','na'])
def filter_adjectives_nouns(text):
    # Tokenize le texte
    tokenizer = RegexpTokenizer(r'\w+')
    words = tokenizer.tokenize(text)
    words = [word.lower() for word in words if word.lower() not in stop_words ]

    pos_tags = pos_tag(words)

    adjectives_nouns = [word for word, pos in pos_tags if pos.startswith('NN') or pos.startswith('JJ')]

    return adjectives_nouns

# %%
data['selected'] = data['lyrics'].apply(filter_adjectives_nouns)

# %%
# Create dictionary and corpus
dictionary = corpora.Dictionary(data['selected'])
corpus = [dictionary.doc2bow(text) for text in data['selected']]

# Apply LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Print the topics
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# Get the topic distribution for each document
topic_distribution = lda_model[corpus]

# Add topic distribution to DataFrame
data['topic_distribution'] = topic_distribution
# Out:
# Topic: 0
# Words: 0.010*"word" + 0.009*"niggas" + 0.008*"life" + 0.008*"jump" + 0.008*"shit" + 0.008*"wanna" + 0.006*"ha" + 0.006*"cause" + 0.006*"nigga" + 0.005*"fuck"
# Topic: 1
# Words: 0.013*"fight" + 0.011*"power" + 0.009*"hop" + 0.009*"heart" + 0.008*"props" + 0.008*"dum" + 0.008*"evil" + 0.007*"walk" + 0.007*"man" + 0.007*"dee"
# Topic: 2
# Words: 0.018*"time" + 0.017*"love" + 0.016*"baby" + 0.015*"way" + 0.011*"life" + 0.010*"gonna" + 0.010*"cause" + 0.010*"night" + 0.010*"heart" + 0.009*"wanna"
# Topic: 3
# Words: 0.011*"rock" + 0.009*"ah" + 0.009*"music" + 0.009*"wild" + 0.008*"hot" + 0.007*"break" + 0.007*"chief" + 0.007*"girl" + 0.007*"nigga" + 0.006*"city"
# Topic: 4
# Words: 0.028*"high" + 0.018*"time" + 0.014*"man" + 0.014*"good" + 0.009*"cause" + 0.008*"slow" + 0.007*"day" + 0.006*"night" + 0.006*"real" + 0.005*"hip"

# %%
# Create a dictionary to store the associations between genre_name and the topic with the maximum probability
topic_genre_associations = {}

# Iterate over each row in the DataFrame
for index, row in data.iterrows():
    # Get the topic with the maximum probability
    max_topic = max(row['topic_distribution'], key=lambda x: x[1])
    
    # Extract the topic index and probability
    max_topic_index, max_topic_prob = max_topic
    
    # Get the corresponding genre_name
    genre_name = row['genre_name']
    
    # Associate the genre_name with the topic index
    topic_genre_associations[index] = (max_topic_index, genre_name)


topic_genre_associations
# Create a dictionary to store the distribution of topics for each genre
genre_topic_distribution = {}

# Iterate over each item in the topic_genre_associations dictionary
for index, (topic_index, genre_name) in topic_genre_associations.items():
    # If the genre_name is not already in the genre_topic_distribution dictionary, add it with an empty list
    if genre_name not in genre_topic_distribution:
        genre_topic_distribution[genre_name] = [0] * lda_model.num_topics
    
# Topic 2: 68
# Topic 3: 1
# Topic 4: 0
# Genre: funk
# Topic 0: 6
# Topic 1: 4
# Topic 2: 47
# Topic 3: 6
# Topic 4: 11
# Genre: new romantic
# Topic 0: 5
# Topic 1: 8
# Topic 2: 68
# Topic 3: 14
# Topic 4: 11
# Genre: disco
# Topic 0: 5
# Topic 1: 3
# Topic 2: 60
# Topic 3: 11
# Topic 4: 3
# Genre: metalcore
# Topic 0: 4
# Topic 1: 9
# Topic 2: 140
# Topic 3: 2
# Topic 4: 1
# Genre: swedish pop
# Topic 0: 0
# Topic 1: 0
# Topic 2: 33
# Topic 3: 3
# Topic 4: 3
# Genre: jazz blues
# Topic 0: 2
# Topic 1: 3
# Topic 2: 37
# Topic 3: 5
# Topic 4: 9
# Genre: hardcore hip hop
# Topic 0: 31
# Topic 1: 8
# Topic 2: 5
# Topic 3: 11
# Topic 4: 22
# Genre: freak folk
# Topic 0: 7
# Topic 1: 10
# Topic 2: 84
# Topic 3: 13
# Topic 4: 20
# Genre: vocal jazz
# Topic 0: 0
# Topic 1: 2
# Topic 2: 47
# Topic 3: 1
# Topic 4: 3
# Genre: east coast hip hop
# Topic 0: 22
# Topic 1: 7
# Topic 2: 3
# Topic 3: 10
# Topic 4: 11

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Assuming 'lda_model' is your trained LDA model
topics = lda_model.show_topics(formatted=False)

# Plot word clouds for each topic
for topic_id, words in topics:
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(words))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Topic {topic_id}')
    plt.axis('off')
    plt.show()

# %%
total_unique_genre_count = df['genre_name'].nunique()

print("Total number of unique genre_name values in the DataFrame:", total_unique_genre_count)
# Out:
# Total number of unique genre_name values in the DataFrame: 113

# %%
unique_genre_counts = df.groupby('cluster')['genre_name'].nunique().reset_index(name='unique_genre_count')

print(unique_genre_counts)
# Out:
#    cluster  unique_genre_count
# 0        0                 108
# 1        1                 100
# 2        2                 103
# 3        3                 111
# 4        4                 109

# %%
df = pd.read_csv('../Data/cluster_assigne.csv', sep = ";")
df
# Out:
#                    spotify_id                 name              artist  \
# 0      3B7i9OKRRmIsSBHEbJz58Y        Grind With Me        Pretty Ricky
# 1      0kPgn96FXEO9Bnz9QN1Tc0        We In Da City           Young Dro
# 2      6Y9kdB2O0h9gq9y2vclsWT    Shorty Wanna Ride          Young Buck
# 3      0svl7cK07gK1ia5ainczU5        Break Ya Neck        Busta Rhymes
# 4      1DFPibRb9RU3yfM3wOLdDT                  Tru               Lloyd
# ...                       ...                  ...                 ...
# 10301  35kAc40pbM9VpzQvnNMAZO             Raw Shit              Jaylib
# 10302  46ePNyvaDBKsxusDXDj7Wg              Wipeout            Fat Boys
# 10303  6msTUCqIfVOWe7pzWGzh6F     Leaving the Past  Immortal Technique
# 10304  5o7zlUWDdRlunP9S0OTm9R  Crumbs On the Table              D-Nice
# 10305  41gBEkVcxU4FSjVpOGWxsB       Wild Wild West        Kool Moe Dee
#
#        position          genre_name  \
# 0          10.0             pop rap
# 1          18.0             pop rap
# 2          22.0             pop rap
# 3          28.0             pop rap
# 4          32.0             pop rap
# ...         ...                 ...
# 10301     102.0  east coast hip hop
# 10302     114.0  east coast hip hop
# 10303     118.0  east coast hip hop
# 10304     123.0  east coast hip hop
# 10305     125.0  east coast hip hop
#
#                                                   lyrics language  \
# 0       Ohh Ooh-oh, yeah Hey, hey, hey, yeah  Baby, g...       en
# 1       Yeah yeah Yeah yeah Yeah yeah Yeah yeah Young...       en
# 2       Shorty wanna ride with me (Ride with me) Shor...       en
# 3       Yeah, check it out, see The only thing you ne...       en
# 4       I lost it all, my friends, my loved ones But ...       en
# ...                                                  ...      ...
# 10301   Uh Feel it (Yeah, yeah) Check it now What'd y...       en
# 10302   Hehehehehehee, wipeout  Wiping out, wipeout W...       en
# 10303   They told me I would never make it, I would n...       en
# 10304  (Is that a turntable? Well get on it, it's you...       en
# 10305   The wild wild west The wild wild west The wil...       en
#
#                                                 selected  \
# 0      ['baby', 'grind', 'relax', 'take', 'time', 'de...
# 1      ['young', 'dro', 'turn', 'car', 'roof', 'car',...
# 2      ['shorty', 'wanna', 'ride', 'shorty', 'wanna',...
# 3      ['see', 'thing', 'right', 'nod', 'fuckin', 'he...
# 4      ['friends', 'ones', 'life', 'chance', 'grow', ...
# ...                                                  ...
# 10301  ['feel', 'check', 'come', 'c', 'c', 'kweli', '...
# 10302  ['hehehehehehee', 'wipeout', 'wah', 'wah', 'wa...
# 10303  ['reality', 'nourishment', 'people', 'guess', ...
# 10304  ['turntable', 'turn', 'chicken', 'egg', 'mc', ...
# 10305  ['wild', 'wild', 'west', 'wild', 'wild', 'west...
#
#                                       topic_distribution  cluster
# 0      [(1, 0.58197623), (2, 0.044897072), (3, 0.3423...        1
# 1                                       [(2, 0.9937237)]        2
# 2                                      [(2, 0.99731237)]        2
# 3      [(2, 0.8050929), (3, 0.071661346), (4, 0.12183...        2
# 4      [(1, 0.014604805), (2, 0.08044021), (3, 0.9011...        3
# ...                                                  ...      ...
# 10301  [(1, 0.16330288), (2, 0.7616119), (3, 0.0720665)]        2
# 10302                                  [(0, 0.99447477)]        0
# 10303  [(1, 0.8538106), (2, 0.12584715), (3, 0.018329...        1
# 10304  [(0, 0.054338306), (1, 0.06520732), (2, 0.7037...        2
# 10305                  [(2, 0.15764748), (4, 0.8398148)]        4
#
# [10306 rows x 10 columns]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# List of words for the word cloud
words =['dum','fight','soul','power','world','everybody','humpty','hump','boogie','dance','lead','band',
'burn','many','joy','lives','father','sea','beautiul','ghost','angel','blood','walls','sound']

# Convert the list of words to a string
words_text = ' '.join(words)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(words_text)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from gensim import corpora, models
import pyLDAvis.gensim

# Assuming you have trained an LDA model named "ldamodel"
# and you have the corpus and dictionary used for training the model

# Visualize the topics
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False)
lda_display.topic_info['genre_name'] = topic_genre_df['Most Prevalent Genre']
pyLDAvis.display(lda_display)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3324\75103059.py in <module>
#       7 # Visualize the topics
#       8 lda_display = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False)
# ----> 9 lda_display.topic_info['genre_name'] = topic_genre_df['Most Prevalent Genre']
#      10 pyLDAvis.display(lda_display)
#
# NameError: name 'topic_genre_df' is not defined
